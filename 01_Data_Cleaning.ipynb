# %%
import pandas as pd

# %% [markdown]
# Using the codebook that came with the data to define the column names. Instead of defining the column specs, I found it easier to delim the whitespaces instead.

# %%
# column names
col_names = [
    "SHEET","CHAIN","CO_OWNED","STATE",
    "SOUTHJ","CENTRALJ","NORTHJ","PA1","PA2","SHORE",
    "NCALLS","EMPFT","EMPPT","NMGRS","WAGE_ST","INCTIME","FIRSTINC","BONUS","PCTAFF","MEALS",
    "OPEN","HRSOPEN","PSODA","PFRY","PENTREE","NREGS","NREGS11",
    "TYPE2","STATUS2","DATE2","NCALLS2","EMPFT2","EMPPT2","NMGRS2","WAGE_ST2","INCTIME2","FIRSTIN2","SPECIAL2",
    "MEALS2","OPEN2R","HRSOPEN2","PSODA2","PFRY2","PENTREE2","NREGS2","NREGS112"
]
public_dat_raw = pd.read_csv("public.dat", delim_whitespace=True, header=None, names=col_names)

public_dat_raw.head()
# Out:
# /tmp/ipython-input-688117111.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   public_dat_raw = pd.read_csv("public.dat", delim_whitespace=True, header=None, names=col_names)
#    SHEET  CHAIN  CO_OWNED  STATE  SOUTHJ  CENTRALJ  NORTHJ  PA1  PA2  SHORE  \
# 0     46      1         0      0       0         0       0    1    0      0
# 1     49      2         0      0       0         0       0    1    0      0
# 2    506      2         1      0       0         0       0    1    0      0
# 3     56      4         1      0       0         0       0    1    0      0
# 4     61      4         1      0       0         0       0    1    0      0
#
#    ...  FIRSTIN2 SPECIAL2 MEALS2 OPEN2R HRSOPEN2 PSODA2 PFRY2  PENTREE2  \
# 0  ...      0.08        1      2   6.50    16.50   1.03     .      0.94
# 1  ...      0.05        0      2  10.00    13.00   1.01  0.89      2.35
# 2  ...      0.25        .      1  11.00    11.00   0.95  0.74      2.33
# 3  ...      0.15        0      2  10.00    12.00   0.92  0.79      0.87
# 4  ...      0.15        0      2  10.00    12.00   1.01  0.84      0.95
#
#   NREGS2  NREGS112
# 0      4         4
# 1      4         4
# 2      4         3
# 3      2         2
# 4      2         2
#
# [5 rows x 46 columns]

# %%
len(public_dat_raw)
# Out:
# 410

# %% [markdown]
# public_dat_raw contains all the data we need. survey1.nj and survey2.nj contains the origional survey data but all that info is also contained in public.dat so it isn't needed.
